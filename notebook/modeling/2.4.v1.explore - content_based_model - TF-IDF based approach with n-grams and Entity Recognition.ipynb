# %% [markdown]
# # 2.4.v1 - Modeling - content_based_model - TF-IDF based approach with n-grams and Entity Recognition

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse.csr import csr_matrix #need this if you want to save tfidf_matrix
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics.pairwise import linear_kernel

from collections import Counter, OrderedDict
import re
import ast
import math
import requests, json

# Load library
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# download the set of stop words the first time
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('words')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/cesleemontgomery/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
wiki_page_path_DF = pd.read_csv('../../data/processed/academic_outline_wikipedia_pages.csv')
course_subs_DF = pd.read_csv('../../data/processed/course_data_udacity.csv')

# %%
words = set(nltk.corpus.words.words())

# Building function for easy comparison
def get_counter_from_list(templist, words=words):

    #lowercase,remove punctuation and non-alpha, split whitespace
    templist = " ".join(w for w in nltk.wordpunct_tokenize(str(templist)) \
         if w.lower() in words).lower()
    templist = re.sub("[^a-zA-Z\s]+", "", templist).split()

    # Load stop words, lemmatizer
    stop_words = stopwords.words('english')
    lemma = nltk.wordnet.WordNetLemmatizer()

    # Remove stop words, lowercase, lemmatize
    counter = Counter([lemma.lemmatize(word.lower()) for word in templist if word not in stop_words])
    return counter

# %% [markdown]
# ### 1.0 - N-grams and Entity Recognition
#
# Let's see if N-grams and wikipedia-based Entity Recognition can help our cause.
#
# We want to transform this list of top occuring keywords into an ordered list of **meaningful** keywords.

# %%
tempname = 'Applied Sciences > Medicine and health'
tempdf = wiki_page_path_DF[wiki_page_path_DF.page_path_label == tempname].page_text.values

print("Most Common Words in '{}' course: \n".format(tempname))
for i in get_counter_from_list(tempdf, words).most_common(200): print(i)
# Out:
# Most Common Words in 'Applied Sciences > Medicine and health' course:
#
# ('medicine', 229)
# ('medical', 116)
# ('health', 80)
# ('n', 69)
# ('care', 67)
# ('branch', 60)
# ('study', 38)
# ('treatment', 33)
# ('system', 33)
# ('disease', 31)
# ('surgery', 30)
# ('practice', 29)
# ('patient', 27)
# ('may', 26)
# ('diagnosis', 25)
# ('also', 25)
# ('science', 23)
# ('modern', 22)
# ('general', 20)
# ('knowledge', 19)
# ('history', 19)
# ('many', 19)
# ('concerned', 19)
# ('prevention', 18)
# ('traditional', 17)
# ('include', 17)
# ('physician', 16)
# ('based', 16)
# ('often', 15)
# ('first', 15)
# ('human', 15)
# ('clinical', 14)
# ('surgical', 14)
# ('used', 13)
# ('evidence', 13)
# ('examination', 13)
# ('one', 13)
# ('body', 13)
# ('research', 12)
# ('example', 12)
# ('world', 12)
# ('known', 11)
# ('e', 11)
# ('united', 11)
# ('emergency', 11)
# ('work', 11)
# ('training', 10)
# ('doctor', 10)
# ('development', 10)
# ('well', 10)
# ('laboratory', 10)
# ('primary', 10)
# ('function', 10)
# ('treat', 9)
# ('blood', 9)
# ('provided', 9)
# ('access', 9)
# ('life', 9)
# ('technology', 8)
# ('apply', 8)
# ('ancient', 8)
# ('scientific', 8)
# ('generally', 8)
# ('western', 8)
# ('physical', 8)
# ('diagnostic', 8)
# ('g', 8)
# ('family', 8)
# ('sometimes', 8)
# ('focus', 8)
# ('non', 8)
# ('operative', 8)
# ('field', 8)
# ('especially', 8)
# ('early', 8)
# ('effect', 8)
# ('related', 8)
# ('college', 8)
# ('use', 8)
# ('subject', 8)
# ('illness', 7)
# ('injury', 7)
# ('population', 7)
# ('information', 7)
# ('specific', 7)
# ('various', 7)
# ('delivery', 7)
# ('education', 7)
# ('considered', 7)
# ('hospital', 7)
# ('application', 7)
# ('physic', 7)
# ('royal', 7)
# ('specialty', 7)
# ('two', 7)
# ('require', 7)
# ('management', 7)
# ('ethic', 7)
# ('around', 6)
# ('culture', 6)
# ('folk', 6)
# ('outside', 6)
# ('u', 6)
# ('support', 6)
# ('legal', 6)
# ('social', 6)
# ('main', 6)
# ('organ', 6)
# ('heart', 6)
# ('although', 6)
# ('brain', 6)
# ('significant', 6)
# ('way', 6)
# ('time', 6)
# ('provide', 6)
# ('biological', 6)
# ('internal', 6)
# ('school', 6)
# ('degree', 6)
# ('department', 6)
# ('reproductive', 6)
# ('century', 6)
# ('father', 6)
# ('al', 6)
# ('diagnose', 5)
# ('would', 5)
# ('commonly', 5)
# ('alternative', 5)
# ('trained', 5)
# ('safety', 5)
# ('across', 5)
# ('order', 5)
# ('help', 5)
# ('part', 5)
# ('process', 5)
# ('past', 5)
# ('basis', 5)
# ('large', 5)
# ('therapy', 5)
# ('specialist', 5)
# ('need', 5)
# ('new', 5)
# ('practical', 5)
# ('discipline', 5)
# ('different', 5)
# ('structure', 5)
# ('nervous', 5)
# ('currently', 5)
# ('pathology', 5)
# ('professional', 5)
# ('public', 5)
# ('back', 5)
# ('national', 5)
# ('variety', 4)
# ('genetics', 4)
# ('typically', 4)
# ('radiation', 4)
# ('local', 4)
# ('according', 4)
# ('applied', 4)
# ('molecular', 4)
# ('done', 4)
# ('derived', 4)
# ('even', 4)
# ('literature', 4)
# ('either', 4)
# ('relationship', 4)
# ('relevant', 4)
# ('important', 4)
# ('follow', 4)
# ('similar', 4)
# ('upon', 4)
# ('additional', 4)
# ('provider', 4)
# ('appearance', 4)
# ('eye', 4)
# ('mental', 4)
# ('come', 4)
# ('problem', 4)
# ('individual', 4)
# ('church', 4)
# ('rather', 4)
# ('three', 4)
# ('available', 4)
# ('community', 4)
# ('trauma', 4)
# ('still', 4)
# ('usually', 4)
# ('radiology', 4)
# ('certain', 4)
# ('interpretation', 4)
# ('role', 4)
# ('bacteria', 4)
# ('physiology', 4)
# ('sub', 4)
# ('residency', 4)
# ('north', 4)
# ('common', 4)
# ('complex', 4)
# ('see', 4)

# %% [markdown]
# ### 1.1 - Get List of N-grams up to 4.

# %%
#1. get user model candidates
text = tempdf[0]
ngrams_vec = CountVectorizer(ngram_range=(1,4))
analyzer = ngrams_vec.build_analyzer()
ngrams = analyzer(text)
print(ngrams[0:100])
# Out:
# ['medicine', 'is', 'the', 'science', 'and', 'practice', 'of', 'establishing', 'the', 'diagnosis', 'prognosis', 'treatment', 'and', 'prevention', 'of', 'disease', 'medicine', 'encompasses', 'variety', 'of', 'health', 'care', 'practices', 'evolved', 'to', 'maintain', 'and', 'restore', 'health', 'by', 'the', 'prevention', 'and', 'treatment', 'of', 'illness', 'contemporary', 'medicine', 'applies', 'biomedical', 'sciences', 'biomedical', 'research', 'genetics', 'and', 'medical', 'technology', 'to', 'diagnose', 'treat', 'and', 'prevent', 'injury', 'and', 'disease', 'typically', 'through', 'pharmaceuticals', 'or', 'surgery', 'but', 'also', 'through', 'therapies', 'as', 'diverse', 'as', 'psychotherapy', 'external', 'splints', 'and', 'traction', 'medical', 'devices', 'biologics', 'and', 'ionizing', 'radiation', 'amongst', 'others', 'medicine', 'has', 'been', 'around', 'for', 'thousands', 'of', 'years', 'during', 'most', 'of', 'which', 'it', 'was', 'an', 'art', 'an', 'area', 'of', 'skill']

# %%
len(ngrams)
# Out:
# 36190

# %% [markdown]
# ### 1.2 - Filter through wikipedia-based entity map
#
# For time's sake a more efficient/quality way to check whether a word is an entity is to check it against Wikipedia titles.  This hack is likely to be a better bet because Wikipedia covers highly specific academic topics that might be hard to pull from existing named entity corpuses.

# %%
#1.1 some pre-processing

"""remove punctuation and non-alpha, split whitespace, lowercase, lemmatize"""
def preprocess_token(token):
    
        # Load stop words, lemmatizer
    stop_words = stopwords.words('english')
    lemma = nltk.wordnet.WordNetLemmatizer()

    processed_token = lemma.lemmatize( \
                            re.sub("[^a-zA-Z\s]+", "", token) \
                        .lower())
    if processed_token not in stop_words:
        return processed_token
    else:
        return None

ngrams_cleaned = set(filter(None, map(preprocess_token, ngrams)))
print(len(ngrams_cleaned), next(iter(ngrams_cleaned)))
# Out:
# 23971 but the

# %%
#2. get wiki NER corpus
wiki_titles = set(token.lower() for token in open("../../data/raw/articletitles_wikipedia/enwiki-latest-all-titles-in-ns0.txt", "r") \
                .read().splitlines())
len(wiki_titles)
# Out:
# 13870304

# %%
def is_not_type_disambiguation_page(title):
    url = """https://en.wikipedia.org/api/rest_v1/page/summary/{title}""".format(title=title)

    response = requests.get(url)
    if response.status_code == 200:
        data = json.loads(response.text)
        if data['type'] != 'disambiguation':
            return True
        else:
            return False

# tempset = set(map(lambda token: token.replace(" ", "_"), ngrams_cleaned))
# ngrams_search_patterns = tempset | set('{token}_(computing)'.format(token=g) for g in ngrams_search_patterns)
# ngrams_search_patterns_matches = set.intersection(ngrams_search_patterns, wiki_titles)
ngrams_search_patterns_matches_nondisambiguated = filter(lambda title: is_not_type_disambiguation_page(title), ngrams_search_patterns_matches)
user_model_entities = set(map(lambda token: token.replace("_(computing)", "").replace("_", " "), ngrams_search_patterns_matches_nondisambiguated))

# %% [markdown]
# Let's see how we did by filtering out ngrams given identification as a wikipedia-based entity...

# %%
len(ngrams_search_patterns_matches)
# Out:
# 2750

# %%
ngrams_search_patterns_matches
# Out:
# {'ethnography',
#  'prescribing',
#  'great',
#  'mixed',
#  'tension',
#  'visual arts',
#  'developed',
#  'bc',
#  'visceral',
#  'take care',
#  'separation',
#  'sens',
#  'herbal medicines',
#  'pharmacopoeia',
#  'hobby',
#  'from one',
#  'for example',
#  'whole',
#  'action',
#  'indicator',
#  'family members',
#  'highly',
#  'design',
#  'certain',
#  'textbook',
#  'to each',
#  'said',
#  'application',
#  'healthcare provider',
#  'continue',
#  'vascular',
#  'podiatric',
#  'sampling',
#  'cardiology',
#  'lutz',
#  'the canon of medicine',
#  'for all',
#  'mechanic',
#  'luria',
#  'the study',
#  'weight',
#  'endoscopy',
#  'flying',
#  'nafis',
#  'the digestive system',
#  'bimaristan',
#  'medieval islamic medicine',
#  'the black',
#  'word',
#  'emission computed tomography',
#  'gain',
#  'science and technology',
#  'all ages',
#  'possession',
#  'impacted',
#  'humani',
#  'given',
#  'evolve',
#  'unnecessary health care',
#  'religion',
#  'overtone',
#  'history',
#  'ordering',
#  'radiopharmaceutical',
#  'the skin',
#  'evolution',
#  'modern era',
#  'weapon',
#  'plant',
#  'elderly',
#  'chemical components',
#  'and how',
#  'biopsy',
#  'commercial',
#  'defines',
#  'personal gain',
#  'hybridization',
#  'thinking',
#  'there is',
#  'mechanism',
#  'burn',
#  'nation',
#  'philosophical',
#  'hyperbaric medicine',
#  'usually',
#  'reconstruction',
#  'medica',
#  'se',
#  'royal college',
#  'van',
#  'age of',
#  'climate',
#  'crisis',
#  'prevention of disease',
#  'specific',
#  'intensive care',
#  'period',
#  'brazil',
#  'the cochrane collaboration',
#  'five books of moses',
#  'emotional',
#  'korean',
#  'epistemological',
#  'well',
#  'take',
#  'surgical',
#  'decade',
#  'intentionally',
#  'at work',
#  'program',
#  'learning',
#  'part',
#  'electrical activity',
#  'peripheral',
#  'type',
#  'airway',
#  'equality',
#  'national',
#  'gyn',
#  'salus',
#  'damage',
#  'home care',
#  'black death',
#  'modern medicine',
#  'andreas vesalius',
#  'biliary',
#  'status',
#  'visual',
#  'external',
#  'food',
#  'the sick',
#  'brain',
#  'abulcasis',
#  'covered',
#  'emerging',
#  'medical school',
#  'neurology',
#  'endocrine system',
#  'value',
#  'prevention',
#  'disproved',
#  'membership',
#  'scientific discipline',
#  'evolutionary medicine',
#  'edward',
#  'gross',
#  'human brain',
#  'leiden',
#  'health',
#  'cytogenetics',
#  'observable',
#  'otolaryngology',
#  'diagnostic specialties',
#  'allergy',
#  'periods of history',
#  'laboratory techniques',
#  'vaccination',
#  'urban',
#  'family tree',
#  'chemical',
#  'availability',
#  'oral and maxillofacial surgery',
#  'doctor of osteopathic',
#  'italy',
#  'podiatric medicine',
#  'see also',
#  'sexual medicine',
#  'text',
#  'salvador luria',
#  'eighth',
#  'shorter',
#  'designed',
#  'conflict',
#  'willing',
#  'missed',
#  'review',
#  'combining',
#  'genomics',
#  'social science',
#  'kind',
#  'driven',
#  'ritually',
#  'social history',
#  'listen',
#  'patient safety',
#  'registered',
#  'authority',
#  'the potential',
#  'testing',
#  'institution',
#  'splint',
#  'barrier',
#  'the united kingdom',
#  'cranial',
#  'medication',
#  'anaesthesia',
#  'percussion',
#  'systematic',
#  'perhaps',
#  'avicenna',
#  'ultrasonography',
#  'version',
#  'communion',
#  'institutiones',
#  'scholarly',
#  'relationship',
#  'transmission',
#  'interaction',
#  'list',
#  'sulfa drugs',
#  'responsible',
#  'the immune system',
#  'practice',
#  'medieval europe',
#  'chief complaint',
#  'convalescence',
#  'thought',
#  'discovered',
#  'facility',
#  'people',
#  'pediatric',
#  'trainee',
#  'pierre fauchard',
#  'louis',
#  'gallbladder',
#  'michael',
#  'exacerbation',
#  'founded',
#  'wikiquote',
#  'the process',
#  'blood tests',
#  'primary',
#  'vinca',
#  'orientation',
#  'travel addiction',
#  'limit',
#  'thing',
#  'plan',
#  'ha',
#  'still',
#  'camera',
#  'monogenic',
#  'record',
#  'cathedral schools',
#  'roman medicine',
#  'outside',
#  'at the end',
#  'pulmonology',
#  'volume',
#  'in conflict',
#  'asaph the jew',
#  'survey',
#  'blood transfusions',
#  'relief',
#  'care',
#  'context',
#  'schola medica salernitana',
#  'per',
#  'the practice',
#  'jurisdiction',
#  'environmental medicine',
#  'circle',
#  'united states of america',
#  'high risk pregnancy',
#  'entail',
#  'gross anatomy',
#  'anesthesia',
#  'scale',
#  'manage',
#  'famine',
#  'chemistry',
#  'diving medicine',
#  'scarce',
#  'avenzoar',
#  'male',
#  'also known as',
#  'history philosophy',
#  'medical practitioners',
#  'tropical medicine',
#  'information',
#  'practitioner',
#  'complaint',
#  'immunohistochemistry',
#  'medicinal plants',
#  'medical science',
#  'folk medicine',
#  'perform',
#  'vocational',
#  'taxol',
#  'observed',
#  'organ system',
#  'congenital',
#  'on the way',
#  'the end',
#  'establishing',
#  'foot',
#  'state owned',
#  'medical ethics',
#  'arab',
#  'defining',
#  'government',
#  'studying',
#  'temperate',
#  'hospice',
#  'the government',
#  'the historian',
#  'wikisource',
#  'joseph',
#  'researcher',
#  'best',
#  'assurance',
#  'least',
#  'adult',
#  'light',
#  'pharmacogenomics',
#  'counter',
#  'rehabilitation',
#  'whether',
#  'interdisciplinary',
#  'range',
#  'tome',
#  'organization',
#  'doctor of osteopathic medicine',
#  'method',
#  'empire',
#  'investigation',
#  'sociology',
#  'telling',
#  'gynecology',
#  'legal',
#  'continued',
#  'eating disorders',
#  'sitting',
#  'combination',
#  'gamma',
#  'definitive',
#  'the elderly',
#  'come',
#  'depressor',
#  'to be',
#  'african',
#  'finish',
#  'maxillofacial',
#  'gave',
#  'post',
#  'algiatry',
#  'within',
#  'the first time',
#  'evoked potential',
#  'pasteur',
#  'tuskegee',
#  'this is',
#  'maurice',
#  'presenting complaint',
#  'identification',
#  'neurosurgery',
#  'medical nutrition therapy',
#  'royal college of surgeons',
#  'return',
#  'answer',
#  'discussion',
#  'psychiatric',
#  'even though',
#  'attained',
#  'anyone',
#  'medical practice',
#  'running',
#  'heart failure',
#  'torah',
#  'highlight',
#  'magnetic resonance',
#  'fit',
#  'william',
#  'categorize',
#  'ancient greek',
#  'instrumental',
#  'gynaecological',
#  'psychiatry',
#  'benedictine',
#  'broad',
#  'the public',
#  'united kingdom',
#  'primary care',
#  'heavily',
#  'fluorescent',
#  'paroxysm',
#  'etymology',
#  'united states',
#  'medical anthropology',
#  'photon',
#  'formal',
#  'the western',
#  'africa',
#  'legal document',
#  'class',
#  'expensive',
#  'uremia',
#  'dietitian',
#  'enough',
#  'theological',
#  'discipline',
#  'licensed',
#  'medical decision making',
#  'hold',
#  'tear',
#  'groundbreaking',
#  'complex',
#  'gradual',
#  'space',
#  'owned',
#  'nursing',
#  'maintenance',
#  'health professionals',
#  'kahun',
#  'ideal',
#  'purpose',
#  'neurological',
#  'oxygen',
#  'biomedical sciences',
#  'physical',
#  'de',
#  'female reproductive systems',
#  'genetic',
#  'local community',
#  'die',
#  'influential',
#  'the pharmacist',
#  'skin',
#  'postoperative pain',
#  'endocrinology',
#  'molecular',
#  'historian',
#  'ireland',
#  'rate',
#  'animism',
#  'amateur',
#  'entrance examination',
#  'basic',
#  'team',
#  'pas',
#  'surgery',
#  'theoretical',
#  'notable',
#  'diagnostics',
#  'postgraduate',
#  'function',
#  'the us',
#  'health and disease',
#  'order of',
#  'sub',
#  'prehistoric',
#  'substance',
#  'role',
#  'aerospace medicine',
#  'disorder',
#  'sri lanka',
#  'taking',
#  'gut',
#  'the ancient',
#  'understanding',
#  'medical herbs',
#  'loss',
#  'would',
#  'assessment',
#  'cytology',
#  'the new',
#  'practical',
#  'tertiary care',
#  'bacteria',
#  'medical care',
#  'traditional african medicine',
#  'since',
#  'addiction medicine',
#  'operative',
#  'culture and society',
#  'detail',
#  'transmitted',
#  'divination',
#  'base',
#  'in fact',
#  'light microscopy',
#  'lag',
#  'james watson',
#  'easily',
#  'the decision',
#  'genetic disorders',
#  'vital organs',
#  'compatibility',
#  'political',
#  'herb',
#  'diagnostic radiology',
#  'derangement',
#  'andreas',
#  'etiology',
#  'not the first',
#  'health professions',
#  'branched',
#  'biological inheritance',
#  'surgical technologist',
#  'genitalia',
#  'the chief',
#  'cc',
#  'close',
#  'medical treatment',
#  'osler',
#  'hereditary',
#  'date',
#  'chronological',
#  'across',
#  'east',
#  'the components',
#  'associated',
#  'play',
#  'major',
#  'medical degree',
#  'truthfulness',
#  'benedictine order',
#  'well known',
#  'the edwin',
#  'ear',
#  'difficult',
#  'generation',
#  'universal',
#  'biologics',
#  'respiratory system',
#  'body temperature',
#  'order',
#  'occasion',
#  'engaged',
#  'the same',
#  'prefer',
#  'operating room',
#  'subject',
#  'female',
#  'cesalpino',
#  'evidenced',
#  'divided',
#  'computer',
#  'agency',
#  'mri',
#  'highlighted',
#  'ethic',
#  'pre',
#  'veterinarian',
#  'connection',
#  'primum non nocere',
#  'electromyography',
#  'biostatistics',
#  'the physician',
#  'environmental',
#  'german',
#  'the great',
#  'they remain',
#  'site',
#  'chinese',
#  'situation',
#  'the european',
#  'maxillofacial surgery',
#  'deceased',
#  'took',
#  'transcription',
#  'the brain',
#  'must',
#  'subspecialty',
#  'cancer',
#  'fellowship',
#  'general medicine',
#  'patient',
#  'shaman',
#  'scotland',
#  'blood vessels',
#  'nervous',
#  'disaster',
#  'time in',
#  'pallor',
#  'variety',
#  'assay',
#  'testable',
#  'book',
#  'taking place',
#  'wilkins',
#  'by passing',
#  'consciousness',
#  'pain medicine',
#  'adolfo',
#  'ionizing',
#  'family practice',
#  'treat',
#  'traditional medicines',
#  'scope',
#  'fertility',
#  'systematic reviews',
#  'speech',
#  'respiratory',
#  'place',
#  'pathway',
#  'average',
#  'wa',
#  'al',
#  'the indian',
#  'global',
#  'egypt',
#  'stethoscope',
#  'requirement',
#  'presenting',
#  'diagnosed',
#  'dispensing',
#  'neurotransmitter',
#  'william williams',
#  'lab',
#  'including',
#  'smith',
#  'new zealand',
#  'bernard',
#  'resource',
#  'microorganism',
#  'differential',
#  'underlying',
#  'unnecessary',
#  'over the counter',
#  'the early',
#  'contract',
#  'contemporary movement',
#  'new history',
#  'spanish',
#  'material',
#  'western europe',
#  'due',
#  'nikolai korotkov',
#  'occupational medicine',
#  'collecting',
#  'th',
#  'fever',
#  'male reproductive system',
#  'determine',
#  'ethical dilemma',
#  'eastern roman',
#  'two',
#  'early work',
#  'critical care',
#  'necessarily',
#  'pupil',
#  'negative',
#  'fee',
#  'medical field',
#  'the arts',
#  'christian',
#  'single payer health care',
#  'neoplastic',
#  'up to',
#  'mental disorders',
#  'the word',
#  'in situ hybridization',
#  'robert',
#  'incentive',
#  'apply',
#  'in time',
#  'act in',
#  'primary care provider',
#  'candidate',
#  'covering',
#  'cardiovascular surgery',
#  'prayer',
#  'voluntas',
#  'the knowledge',
#  'fall',
#  'literature',
#  'bodily function',
#  'ce',
#  'sick',
#  'united states and canada',
#  'alexander',
#  'scan',
#  'cellular pathology',
#  'charity',
#  'professional',
#  'list of life sciences',
#  'auscultation',
#  'epidemic',
#  'nightingale',
#  'completed',
#  'nerve',
#  'watson',
#  'principle',
#  'muslim',
#  'medical geology',
#  'royal college of anaesthetists',
#  'shift',
#  'salerno',
#  'general practice',
#  'technologist',
#  'conservative',
#  'laboratory medicine',
#  'clinic',
#  'remain',
#  'the finest',
#  'classical chinese medicine',
#  'rule',
#  'side',
#  'humorism',
#  'randomized control trial',
#  'everything',
#  'materia',
#  'travel medicine',
#  'asian countries',
#  'pregnancy',
#  'teaching',
#  'ct scanner',
#  'monastery',
#  'rejection',
#  'ocular',
#  'distinguishable',
#  'primary health care',
#  'fish',
#  'result',
#  'variation',
#  'neuroscience',
#  'laboratory',
#  'information science',
#  'iranian',
#  'inquiry',
#  'century',
#  'website',
#  'science centre',
#  'shamanism',
#  'management',
#  'magnetic resonance tomography',
#  'relevant',
#  'god',
#  'imaged',
#  'us',
#  'outline',
#  'system',
#  'pain',
#  'psychotherapy',
#  'restore',
#  'addiction',
#  'identified',
#  'safe',
#  'ae',
#  'potential',
#  'protocol',
#  'urgent',
#  'doctor of medicine',
#  'chain reaction',
#  'wikimedia commons',
#  'used',
#  'pathological',
#  'ancestor',
#  'angiology',
#  'advent',
#  'preparedness',
#  'home remedies',
#  'core',
#  'ill',
#  'syphilis',
#  'positive',
#  'the commonwealth',
#  'life',
#  'obstetrics and gynecology',
#  'infirmary',
#  'perspective',
#  'middle',
#  'medical community',
#  'oral',
#  'country',
#  'the eighth',
#  'clarification',
#  'notion',
#  'criminal',
#  'the surgeon',
#  'eea',
#  'infectious disease',
#  'the united',
#  'the eu',
#  'college of surgeons',
#  'academic',
#  'jean martin',
#  'synthesis',
#  'radionuclide',
#  'entry',
#  'family medicine',
#  'make',
#  'tissue',
#  'available',
#  'matter',
#  'went',
#  'interdisciplinary team',
#  'definition',
#  'truly',
#  'health care systems',
#  'kingdom',
#  'otto',
#  'tropical diseases',
#  'multiple',
#  'drum',
#  'cushing',
#  'wiktionary',
#  'also',
#  'appeal to',
#  'area',
#  'heart',
#  'crick',
#  'meta',
#  'tribal societies',
#  'possible',
#  'ancient iranian',
#  'cultural studies',
#  'ensure',
#  'medical history',
#  'another',
#  'rudolf',
#  'recording',
#  'medicinal',
#  'there are',
#  'medical professional',
#  'human body',
#  'one',
#  'delivery',
#  'early records',
#  'head',
#  'decision',
#  'employed',
#  'sh',
#  'musculoskeletal',
#  'process',
#  'effective',
#  'member',
#  'like',
#  'made',
#  'becoming',
#  'dating',
#  'conservation medicine',
#  'medicine men',
#  'medical genetics',
#  'medium',
#  'william coley',
#  'object',
#  'one or the other',
#  'tertiary',
#  'port of call',
#  'north',
#  'enquiry',
#  'removal',
#  'the reaction',
#  'radiation oncology',
#  'emporiatrics',
#  'improvement',
#  'topic',
#  'making',
#  'call',
#  'the western roman empire',
#  'nervous system',
#  'hour',
#  'limb',
#  'generate',
#  'karl landsteiner',
#  'elsewhere',
#  'referral',
#  'emitter',
#  'lower back',
#  'hospital',
#  'to science',
#  'self',
#  'hippocratic oath',
#  'policy',
#  'fabrica',
#  'obstetrics',
#  'it was',
#  'variable',
#  'physical examination',
#  'ct',
#  'acupuncture',
#  'the family',
#  'product',
#  'ultrasound',
#  'health informatics',
#  'toxic',
#  'radiology',
#  'produced',
#  'finest',
#  'experiment',
#  'control',
#  'prominent',
#  'tribal',
#  'humanity',
#  'the doctor',
#  'bloodletting',
#  'ancient egyptian',
#  'curriculum',
#  'the ancient world',
#  'treatment',
#  'later',
#  'environmental health',
#  'the concept',
#  'traditional korean medicine',
#  'visit',
#  'health care',
#  'planning',
#  'genetic material',
#  'be used to',
#  'catholic',
#  'residence',
#  'access to information',
#  'preventive care',
#  'openness',
#  'exclude',
#  'the general',
#  'paul',
#  'nutritional',
#  'european universities',
#  'often',
#  'the scope',
#  'name',
#  'siddha',
#  'herbal',
#  'diagnostic sampling',
#  'called',
#  'bias',
#  'biotechnology',
#  'bronze',
#  'three years',
#  'temperate climates',
#  'the french',
#  'knowledge systems',
#  'in europe',
#  'magnetic',
#  'maurice wilkins',
#  'remedy',
#  'increasingly',
#  'radiographer',
#  'revered',
#  'college of anaesthetists',
#  'evolutionary',
#  'help',
#  'medical facilities',
#  'medical professionals',
#  'family history',
#  'black',
#  'preliminary',
#  'biological tissues',
#  'healthcare',
#  'refuse',
#  'fertility medicine',
#  'literature reviews',
#  'nerve conduction',
#  'curing',
#  'harvey',
#  'first time',
#  'farmland',
#  'emergency preparedness',
#  'flow',
#  'inspection',
#  'medical signs',
#  'mrcs',
#  'modern healthcare',
#  'life support',
#  'diagnose',
#  'course',
#  'hearing damage',
#  'problem',
#  'umbrella',
#  'reader',
#  'hebrew',
#  'presumed',
#  'human genetics',
#  'and then',
#  'need',
#  'compiled',
#  'work',
#  'lower',
#  'evidence based',
#  'insufficient evidence',
#  'edwin smith',
#  'taken',
#  'cell',
#  'medical laboratory',
#  'emergency',
#  'clinical microbiology',
#  'endocrine',
#  'database',
#  'the father',
#  'intervention',
#  'phlebotomy',
#  'perforated',
#  'mood',
#  'frcs',
#  'coley',
#  'pediatrician',
#  'acute',
#  'followed',
#  'inadequate',
#  'physical medicine and rehabilitation',
#  'learned',
#  'pet scan',
#  'pathology',
#  'national library',
#  'centre',
#  'therapy',
#  'nosokinetics',
#  ...}

# %% [markdown]
# Not bad... I can tell there are still some pages that don't look right like "whole"... can we remove these likely disambiguation pages?

# %%
len(ngrams_search_patterns_matches_nondisambiguated)
# Out:
# 1705

# %%
ngrams_search_patterns_matches_nondisambiguated
# Out:
# {'ethnography',
#  'visual arts',
#  'developed',
#  'visceral',
#  'sens',
#  'herbal medicines',
#  'pharmacopoeia',
#  'hobby',
#  'family members',
#  'design',
#  'certain',
#  'textbook',
#  'said',
#  'application',
#  'healthcare provider',
#  'vascular',
#  'podiatric',
#  'cardiology',
#  'lutz',
#  'for all',
#  'mechanic',
#  'weight',
#  'endoscopy',
#  'nafis',
#  'bimaristan',
#  'medieval islamic medicine',
#  'word',
#  'emission computed tomography',
#  'science and technology',
#  'all ages',
#  'unnecessary health care',
#  'religion',
#  'overtone',
#  'history',
#  'radiopharmaceutical',
#  'evolution',
#  'modern era',
#  'weapon',
#  'plant',
#  'elderly',
#  'chemical components',
#  'and how',
#  'biopsy',
#  'defines',
#  'thinking',
#  'there is',
#  'burn',
#  'nation',
#  'philosophical',
#  'hyperbaric medicine',
#  'usually',
#  'medica',
#  'royal college',
#  'van',
#  'climate',
#  'crisis',
#  'prevention of disease',
#  'intensive care',
#  'brazil',
#  'emotional',
#  'epistemological',
#  'well',
#  'take',
#  'surgical',
#  'decade',
#  'intentionally',
#  'program',
#  'learning',
#  'electrical activity',
#  'peripheral',
#  'airway',
#  'salus',
#  'gyn',
#  'damage',
#  'home care',
#  'black death',
#  'modern medicine',
#  'biliary',
#  'visual',
#  'food',
#  'brain',
#  'abulcasis',
#  'emerging',
#  'medical school',
#  'neurology',
#  'endocrine system',
#  'disproved',
#  'scientific discipline',
#  'evolutionary medicine',
#  'edward',
#  'human brain',
#  'leiden',
#  'health',
#  'cytogenetics',
#  'observable',
#  'otolaryngology',
#  'diagnostic specialties',
#  'allergy',
#  'periods of history',
#  'laboratory techniques',
#  'vaccination',
#  'family tree',
#  'chemical',
#  'availability',
#  'oral and maxillofacial surgery',
#  'italy',
#  'podiatric medicine',
#  'sexual medicine',
#  'designed',
#  'missed',
#  'review',
#  'genomics',
#  'social science',
#  'ritually',
#  'social history',
#  'patient safety',
#  'authority',
#  'testing',
#  'institution',
#  'the united kingdom',
#  'medication',
#  'anaesthesia',
#  'percussion',
#  'avicenna',
#  'ultrasonography',
#  'scholarly',
#  'interaction',
#  'sulfa drugs',
#  'list',
#  'chief complaint',
#  'convalescence',
#  'thought',
#  'discovered',
#  'people',
#  'pediatric',
#  'trainee',
#  'gallbladder',
#  'michael',
#  'exacerbation',
#  'wikiquote',
#  'blood tests',
#  'vinca',
#  'travel addiction',
#  'plan',
#  'still',
#  'camera',
#  'cathedral schools',
#  'roman medicine',
#  'pulmonology',
#  'volume',
#  'blood transfusions',
#  'relief',
#  'context',
#  'jurisdiction',
#  'environmental medicine',
#  'circle',
#  'united states of america',
#  'high risk pregnancy',
#  'entail',
#  'gross anatomy',
#  'anesthesia',
#  'scale',
#  'manage',
#  'famine',
#  'chemistry',
#  'diving medicine',
#  'scarce',
#  'avenzoar',
#  'male',
#  'also known as',
#  'history philosophy',
#  'medical practitioners',
#  'tropical medicine',
#  'information',
#  'complaint',
#  'immunohistochemistry',
#  'medicinal plants',
#  'medical science',
#  'folk medicine',
#  'perform',
#  'vocational',
#  'taxol',
#  'observed',
#  'organ system',
#  'congenital',
#  'foot',
#  'state owned',
#  'medical ethics',
#  'arab',
#  'defining',
#  'government',
#  'studying',
#  'temperate',
#  'hospice',
#  'the government',
#  'wikisource',
#  'joseph',
#  'researcher',
#  'adult',
#  'light',
#  'pharmacogenomics',
#  'whether',
#  'interdisciplinary',
#  'organization',
#  'doctor of osteopathic medicine',
#  'method',
#  'empire',
#  'sociology',
#  'gynecology',
#  'legal',
#  'continued',
#  'eating disorders',
#  'sitting',
#  'combination',
#  'gamma',
#  'the elderly',
#  'depressor',
#  'to be',
#  'maxillofacial',
#  'algiatry',
#  'evoked potential',
#  'pasteur',
#  'tuskegee',
#  'presenting complaint',
#  'neurosurgery',
#  'medical nutrition therapy',
#  'discussion',
#  'psychiatric',
#  'attained',
#  'anyone',
#  'medical practice',
#  'running',
#  'heart failure',
#  'torah',
#  'william',
#  'categorize',
#  'ancient greek',
#  'instrumental',
#  'gynaecological',
#  'psychiatry',
#  'benedictine',
#  'united kingdom',
#  'primary care',
#  'fluorescent',
#  'paroxysm',
#  'etymology',
#  'united states',
#  'medical anthropology',
#  'photon',
#  'africa',
#  'legal document',
#  'class',
#  'expensive',
#  'uremia',
#  'dietitian',
#  'theological',
#  'discipline',
#  'licensed',
#  'groundbreaking',
#  'gradual',
#  'space',
#  'owned',
#  'nursing',
#  'health professionals',
#  'purpose',
#  'neurological',
#  'oxygen',
#  'biomedical sciences',
#  'female reproductive systems',
#  'local community',
#  'skin',
#  'postoperative pain',
#  'endocrinology',
#  'molecular',
#  'historian',
#  'ireland',
#  'animism',
#  'amateur',
#  'entrance examination',
#  'team',
#  'surgery',
#  'theoretical',
#  'notable',
#  'diagnostics',
#  'postgraduate',
#  'function',
#  'health and disease',
#  'order of',
#  'prehistoric',
#  'sri lanka',
#  'role',
#  'aerospace medicine',
#  'taking',
#  'understanding',
#  'medical herbs',
#  'would',
#  'cytology',
#  'the new',
#  'practical',
#  'tertiary care',
#  'bacteria',
#  'medical care',
#  'addiction medicine',
#  'transmitted',
#  'divination',
#  'light microscopy',
#  'lag',
#  'james watson',
#  'genetic disorders',
#  'vital organs',
#  'compatibility',
#  'political',
#  'herb',
#  'diagnostic radiology',
#  'derangement',
#  'andreas',
#  'etiology',
#  'health professions',
#  'biological inheritance',
#  'surgical technologist',
#  'genitalia',
#  'medical treatment',
#  'hereditary',
#  'date',
#  'chronological',
#  'east',
#  'major',
#  'medical degree',
#  'benedictine order',
#  'ear',
#  'generation',
#  'biologics',
#  'respiratory system',
#  'body temperature',
#  'engaged',
#  'prefer',
#  'operating room',
#  'female',
#  'cesalpino',
#  'evidenced',
#  'divided',
#  'computer',
#  'mri',
#  'ethic',
#  'veterinarian',
#  'primum non nocere',
#  'electromyography',
#  'biostatistics',
#  'environmental',
#  'the great',
#  'maxillofacial surgery',
#  'deceased',
#  'took',
#  'the brain',
#  'must',
#  'subspecialty',
#  'cancer',
#  'fellowship',
#  'general medicine',
#  'patient',
#  'shaman',
#  'scotland',
#  'blood vessels',
#  'disaster',
#  'pallor',
#  'assay',
#  'testable',
#  'book',
#  'consciousness',
#  'pain medicine',
#  'adolfo',
#  'ionizing',
#  'family practice',
#  'traditional medicines',
#  'fertility',
#  'systematic reviews',
#  'speech',
#  'respiratory',
#  'average',
#  'egypt',
#  'stethoscope',
#  'requirement',
#  'presenting',
#  'diagnosed',
#  'neurotransmitter',
#  'new zealand',
#  'bernard',
#  'resource',
#  'microorganism',
#  'underlying',
#  'unnecessary',
#  'over the counter',
#  'contract',
#  'material',
#  'western europe',
#  'occupational medicine',
#  'collecting',
#  'fever',
#  'male reproductive system',
#  'determine',
#  'ethical dilemma',
#  'two',
#  'necessarily',
#  'pupil',
#  'fee',
#  'medical field',
#  'the arts',
#  'single payer health care',
#  'neoplastic',
#  'up to',
#  'mental disorders',
#  'in situ hybridization',
#  'robert',
#  'incentive',
#  'apply',
#  'in time',
#  'primary care provider',
#  'candidate',
#  'cardiovascular surgery',
#  'prayer',
#  'voluntas',
#  'fall',
#  'literature',
#  'alexander',
#  'cellular pathology',
#  'professional',
#  'list of life sciences',
#  'auscultation',
#  'epidemic',
#  'nightingale',
#  'nerve',
#  'principle',
#  'medical geology',
#  'salerno',
#  'general practice',
#  'conservative',
#  'laboratory medicine',
#  'clinic',
#  'classical chinese medicine',
#  'humorism',
#  'randomized control trial',
#  'everything',
#  'travel medicine',
#  'asian countries',
#  'pregnancy',
#  'teaching',
#  'monastery',
#  'ocular',
#  'primary health care',
#  'fish',
#  'result',
#  'neuroscience',
#  'laboratory',
#  'information science',
#  'inquiry',
#  'century',
#  'website',
#  'science centre',
#  'shamanism',
#  'management',
#  'magnetic resonance tomography',
#  'god',
#  'system',
#  'pain',
#  'psychotherapy',
#  'addiction',
#  'identified',
#  'safe',
#  'potential',
#  'protocol',
#  'doctor of medicine',
#  'chain reaction',
#  'wikimedia commons',
#  'pathological',
#  'ancestor',
#  'angiology',
#  'advent',
#  'preparedness',
#  'home remedies',
#  'syphilis',
#  'life',
#  'obstetrics and gynecology',
#  'infirmary',
#  'medical community',
#  'country',
#  'criminal',
#  'infectious disease',
#  'the united',
#  'the eu',
#  'academic',
#  'radionuclide',
#  'family medicine',
#  'available',
#  'matter',
#  'definition',
#  'interdisciplinary team',
#  'truly',
#  'health care systems',
#  'otto',
#  'tropical diseases',
#  'drum',
#  'wiktionary',
#  'area',
#  'heart',
#  'meta',
#  'tribal societies',
#  'cultural studies',
#  'ensure',
#  'medical history',
#  'rudolf',
#  'medicinal',
#  'there are',
#  'medical professional',
#  'human body',
#  'one',
#  'head',
#  'employed',
#  'process',
#  'musculoskeletal',
#  'effective',
#  'like',
#  'dating',
#  'conservation medicine',
#  'medicine men',
#  'medical genetics',
#  'object',
#  'tertiary',
#  'north',
#  'enquiry',
#  'radiation oncology',
#  'emporiatrics',
#  'improvement',
#  'making',
#  'nervous system',
#  'hour',
#  'lower back',
#  'hospital',
#  'self',
#  'hippocratic oath',
#  'policy',
#  'fabrica',
#  'obstetrics',
#  'variable',
#  'physical examination',
#  'acupuncture',
#  'ultrasound',
#  'health informatics',
#  'toxic',
#  'radiology',
#  'experiment',
#  'control',
#  'tribal',
#  'bloodletting',
#  'curriculum',
#  'environmental health',
#  'health care',
#  'planning',
#  'genetic material',
#  'catholic',
#  'residence',
#  'access to information',
#  'preventive care',
#  'openness',
#  'exclude',
#  'nutritional',
#  'european universities',
#  'often',
#  'name',
#  'siddha',
#  'herbal',
#  'diagnostic sampling',
#  'bias',
#  'biotechnology',
#  'bronze',
#  'temperate climates',
#  'knowledge systems',
#  'magnetic',
#  'increasingly',
#  'radiographer',
#  'revered',
#  'evolutionary',
#  'medical facilities',
#  'medical professionals',
#  'family history',
#  'black',
#  'biological tissues',
#  'healthcare',
#  'refuse',
#  'fertility medicine',
#  'literature reviews',
#  'nerve conduction',
#  'farmland',
#  'emergency preparedness',
#  'inspection',
#  'medical signs',
#  'modern healthcare',
#  'life support',
#  'diagnose',
#  'hearing damage',
#  'problem',
#  'umbrella',
#  'hebrew',
#  'presumed',
#  'human genetics',
#  'need',
#  'compiled',
#  'evidence based',
#  'insufficient evidence',
#  'medical laboratory',
#  'emergency',
#  'clinical microbiology',
#  'endocrine',
#  'database',
#  'personal gain',
#  'phlebotomy',
#  'perforated',
#  'pediatrician',
#  'physical medicine and rehabilitation',
#  'learned',
#  'pet scan',
#  'pathology',
#  'national library',
#  'therapy',
#  'nosokinetics',
#  'infectious diseases',
#  'student',
#  'eu',
#  'byzantine',
#  'biophysics',
#  'academic disciplines',
#  'endemic',
#  'ketoacidosis',
#  'pcr',
#  'palliative medicine',
#  'regulatory authorities',
#  'rheumatology',
#  'digestive tract',
#  'tradition',
#  'truth',
#  'inoculation',
#  'serf',
#  'following',
#  'educated',
#  'biochemistry',
#  'lung',
#  'blood flow',
#  'universally',
#  'shang',
#  'transmission of disease',
#  'prescientific',
#  'religious',
#  'the human brain',
#  'work hours',
#  'schola',
#  'life sciences',
#  'branch of medicine',
#  'nursing home',
#  'tropical',
#  'is not',
#  'health care system',
#  'seed',
#  'injury',
#  'access to medicines',
#  'looking',
#  'devote',
#  'anaesthetist',
#  'hiv',
#  'early middle ages',
#  'human agency',
#  'rather',
#  'biomedical engineering',
#  'scientific',
#  'treatment of disease',
#  'developed countries',
#  'presenting problem',
#  'salernitana',
#  'subsequent',
#  'scientific knowledge',
#  'human',
#  'anesthetist',
#  'several',
#  'toxicology',
#  'smith papyrus',
#  'papyrus',
#  'van leeuwenhoek',
#  'afford',
#  'poor',
#  'laser',
#  'documented',
#  'clinical pharmacology',
#  'reason',
#  'idea',
#  'drink',
#  'upon',
#  'vascular surgery',
#  'time',
#  'modern science',
#  'health sciences',
#  'adaptive immune system',
#  'focus',
#  'hospice and palliative medicine',
#  'medical doctor',
#  'microscope',
#  'france',
#  'mihintale',
#  'unani',
#  'nature',
#  'medicine',
#  'existing',
#  'justice',
#  'america',
#  'theory',
#  'human organ',
#  'six',
#  'azo dyes',
#  'electron',
#  'orthopedic surgery',
#  'harm',
#  'austria',
#  'general appearance',
#  'atropine',
#  'falloppio',
#  'individual',
#  'oncologic surgery',
#  'electrical',
#  'territory',
#  'ebers papyrus',
#  'for any',
#  'general knowledge',
#  'emergence',
#  'organ systems',
#  'latin',
#  'clinical examination',
#  'cochrane collaboration',
#  'used to',
#  'vesting',
#  'single payer',
#  'charlemagne',
#  'orthopedics',
#  'inconsistent',
#  'branches of medicine',
#  'inpatient',
#  'dynasty',
#  'infection',
#  'attending physician',
#  'set',
#  'smallpox vaccine',
#  'photobiology',
#  'trust',
#  'states of america',
#  'physiatry',
#  'moral values',
#  'less than',
#  'measuring',
#  'as of',
#  'clinical laboratory',
#  'nosology',
#  'the senses',
#  'wilderness medicine',
#  'recognize',
#  'millennium',
#  'physician',
#  'history of medicine',
#  'population',
#  'polymerase',
#  'well being',
#  'minimum',
#  'inanimate',
#  'negligent',
#  'ancient world',
#  'insurance',
#  'diagnostic specialty',
#  'catholic church',
#  'ear nose and throat',
#  'eye pupil',
#  'african countries',
#  'upgrade',
#  'australia',
#  'medical nutrition',
#  'exception',
#  'merely',
#  'online',
#  'the respiratory system',
#  'external links',
#  'social',
#  'chemist',
#  'user',
#  'electroencephalography',
#  'effectiveness',
#  'fluorescent in situ hybridization',
#  'explain',
#  'herbal remedies',
#  'averaging',
#  'rapid',
#  'circulatory system',
#  'pandemic',
#  'dye',
#  'university',
#  'computed tomography',
#  'antibiotic',
#  'good',
#  'biomedical research',
#  'competitive',
#  'resonance',
#  'wikibooks',
#  'geriatrician',
#  'healing',
#  'observation',
#  'ambulatory care',
#  'illness',
#  'biological systems',
#  'medical physics',
#  'loewi',
#  'weight loss',
#  'imhotep',
#  'ionizing radiation',
#  'asia',
#  'interest',
#  'eu member states',
#  'scanner',
#  'medical devices',
#  'financing',
#  'shang dynasty',
#  'education',
#  'shift in',
#  'plastic surgery',
#  'embryology',
#  'have been',
#  'radiobiology',
#  'fact',
#  'early development',
#  'clinical medicine',
#  'roman empire',
#  'aspirin',
#  'anatomy',
#  'alcohol',
#  'regional',
#  'ecological',
#  'wealthy',
#  'hormone',
#  'the following',
#  'moses',
#  'temperature',
#  'medicine studies',
#  'hip',
#  'tobacco',
#  'laser medicine',
#  'pediatric surgery',
#  'pharmacist',
#  'wikiversity',
#  'liver',
#  'respiration rate',
#  'western world',
#  'facial',
#  'state',
#  'disaster medicine',
#  'physical therapy',
#  'herbalism',
#  'came',
#  'prehistoric medicine',
#  'gastroenterology',
#  'human evolution',
#  'sir',
#  'pet ct',
#  'humour',
#  'sports medicine',
#  'decreed',
#  'journal',
#  'biological',
#  'general',
#  'arsphenamine',
#  'globally',
#  'malpractice',
#  'clinical immunology',
#  'social care',
#  'rheumatic diseases',
#  'eu member',
#  'nonhuman',
#  'port',
#  'pharmacy',
#  'innate',
#  'reproducible',
#  'hippocrates',
#  'poison',
#  'causative',
#  'analysis',
#  'diagnosis',
#  'seven',
#  'come from',
#  'radiolabelled',
#  'regulatory',
#  'reproductive',
#  'ebers',
#  'terminal illnesses',
#  'human medicine',
#  'in living',
#  'chinese dates',
#  'conference',
#  'accreditation',
#  'environment',
#  'father of',
#  'chronological order',
#  'the heart',
#  'aerospace',
#  'flow cytometry',
#  'physician assistants',
#  'universal health care',
#  'ancient greek medicine',
#  'medieval',
#  'early modern period',
#  'biomechanics',
#  'ancient egyptian medicine',
#  'translated',
#  'harmful',
#  'evolved',
#  'hearing',
#  'biliary system',
#  'attention',
#  'middle ages',
#  'engineering',
#  'occupational',
#  'extent',
#  'death',
#  'life saving',
#  'evidence',
#  'islamic',
#  'concerned',
#  'collaboration',
#  'ancient times',
#  'virchow',
#  'physiology',
#  'meta analysis',
#  'germany',
#  'indigenous medicine',
#  'digoxin',
#  'medical services',
#  'symptom relief',
#  'doctor patient relationship',
#  'habit',
#  'failure',
#  'servetus',
#  'ethical',
#  'pulse',
#  'risk',
#  'entry level',
#  'relapse',
#  'lanka',
#  'how to',
#  'society',
#  'family',
#  'neonatology',
#  'radiation',
#  'nerve conduction study',
#  'respect',
#  'u',
#  'shia',
#  'classification',
#  'clinical chemistry',
#  'tax',
#  'event',
#  'korean medicine',
#  'physiologic',
#  'urinary',
#  'person',
#  'healthcare policy',
#  'medical record',
#  'spasm',
#  'improve',
#  'baby',
#  'hospitalists',
#  'replication',
#  'college',
#  'originally',
#  'national library of medicine',
#  'tribe',
#  'hazardous',
#  'tomography',
#  'concept',
#  'required',
#  'human cells',
#  'wilderness',
#  'anaesthetic',
#  'cause',
#  'lower limb',
#  'solution',
#  'could',
#  'india',
#  'library',
#  'theater',
#  'eating',
#  'gene',
#  'started',
#  'honesty',
#  'utilization review',
#  'belief',
#  'korotkov',
#  'recent',
#  'classical chinese',
#  'orthopedic',
#  'childbirth',
#  ...}

# %% [markdown]
# I feel pretty good about this!! Removes a lot of words that users might consider random if they showed up alongside recommendations.  Again this is important in order to gain their confidence in the system's recommendations.
#
# Let's move on.

# %% [markdown]
# ### 2.0 - TF-IDF of user model wiki-based entities

# %%
len(user_model_entities)
# Out:
# 1693

# %%
#1. use vocabulary user_model_entities to get counts for all user model documents (academic interests)
vectorizer = CountVectorizer(vocabulary=list(user_model_entities), ngram_range=(1,4))
ngram_counts = vectorizer.fit_transform(wiki_page_path_DF.page_text.astype('U'))
#2. get TF-IDF weights
transformer = TfidfTransformer()
tfidf_matrix = transformer.fit_transform(ngram_counts)

# %%
tfidif_df = pd.DataFrame(tfidf_matrix.toarray(), index=wiki_page_path_DF.page_path_label, columns = vectorizer.get_feature_names())
tfidif_df.head()
# Out:
#                                                     ethnography  visual arts  \
# page_path_label
# Humanities                                                  0.0     0.044866
# Humanities > Arts                                           0.0     0.166435
# Humanities > Arts > Performing arts                         0.0     0.043364
# Humanities > Arts > Performing arts > Music                 0.0     0.000000
# Humanities > Arts > Performing arts > Music > A...          0.0     0.000000
#
#                                                     developed  visceral  sens  \
# page_path_label
# Humanities                                           0.009191       0.0   0.0
# Humanities > Arts                                    0.017047       0.0   0.0
# Humanities > Arts > Performing arts                  0.039974       0.0   0.0
# Humanities > Arts > Performing arts > Music          0.034976       0.0   0.0
# Humanities > Arts > Performing arts > Music > A...   0.000000       0.0   0.0
#
#                                                     herbal medicines  \
# page_path_label
# Humanities                                                       0.0
# Humanities > Arts                                                0.0
# Humanities > Arts > Performing arts                              0.0
# Humanities > Arts > Performing arts > Music                      0.0
# Humanities > Arts > Performing arts > Music > A...               0.0
#
#                                                     pharmacopoeia     hobby  \
# page_path_label
# Humanities                                                    0.0  0.000000
# Humanities > Arts                                             0.0  0.000000
# Humanities > Arts > Performing arts                           0.0  0.000000
# Humanities > Arts > Performing arts > Music                   0.0  0.019613
# Humanities > Arts > Performing arts > Music > A...            0.0  0.000000
#
#                                                     family members    design  \
# page_path_label
# Humanities                                                     0.0  0.007141
# Humanities > Arts                                              0.0  0.132454
# Humanities > Arts > Performing arts                            0.0  0.000000
# Humanities > Arts > Performing arts > Music                    0.0  0.000000
# Humanities > Arts > Performing arts > Music > A...             0.0  0.000000
#
#                                                     ...  \
# page_path_label                                     ...
# Humanities                                          ...
# Humanities > Arts                                   ...
# Humanities > Arts > Performing arts                 ...
# Humanities > Arts > Performing arts > Music         ...
# Humanities > Arts > Performing arts > Music > A...  ...
#
#                                                     reproductive medicine  \
# page_path_label
# Humanities                                                            0.0
# Humanities > Arts                                                     0.0
# Humanities > Arts > Performing arts                                   0.0
# Humanities > Arts > Performing arts > Music                           0.0
# Humanities > Arts > Performing arts > Music > A...                    0.0
#
#                                                     office  \
# page_path_label
# Humanities                                             0.0
# Humanities > Arts                                      0.0
# Humanities > Arts > Performing arts                    0.0
# Humanities > Arts > Performing arts > Music            0.0
# Humanities > Arts > Performing arts > Music > A...     0.0
#
#                                                     world health organization  \
# page_path_label
# Humanities                                                                0.0
# Humanities > Arts                                                         0.0
# Humanities > Arts > Performing arts                                       0.0
# Humanities > Arts > Performing arts > Music                               0.0
# Humanities > Arts > Performing arts > Music > A...                        0.0
#
#                                                     ankle      hand  \
# page_path_label
# Humanities                                            0.0  0.000000
# Humanities > Arts                                     0.0  0.000000
# Humanities > Arts > Performing arts                   0.0  0.018858
# Humanities > Arts > Performing arts > Music           0.0  0.028286
# Humanities > Arts > Performing arts > Music > A...    0.0  0.068263
#
#                                                     healthcare system  \
# page_path_label
# Humanities                                                        0.0
# Humanities > Arts                                                 0.0
# Humanities > Arts > Performing arts                               0.0
# Humanities > Arts > Performing arts > Music                       0.0
# Humanities > Arts > Performing arts > Music > A...                0.0
#
#                                                     the wild     chain  \
# page_path_label
# Humanities                                               0.0  0.000000
# Humanities > Arts                                        0.0  0.000000
# Humanities > Arts > Performing arts                      0.0  0.000000
# Humanities > Arts > Performing arts > Music              0.0  0.011266
# Humanities > Arts > Performing arts > Music > A...       0.0  0.000000
#
#                                                     conducted  fungi
# page_path_label
# Humanities                                                0.0    0.0
# Humanities > Arts                                         0.0    0.0
# Humanities > Arts > Performing arts                       0.0    0.0
# Humanities > Arts > Performing arts > Music               0.0    0.0
# Humanities > Arts > Performing arts > Music > A...        0.0    0.0
#
# [5 rows x 1693 columns]

# %%
np.shape(tfidf_matrix)
# Out:
# (985, 1693)

# %%
test_index = 893
cosine_similarities = linear_kernel(tfidf_matrix[test_index:test_index+1], tfidf_matrix).flatten()

# %%
related_docs_indices = cosine_similarities.argsort()[:-10:-1];related_docs_indices
# Out:
# array([893, 732, 926, 981, 894, 971, 689, 284, 443])

# %%
cosine_similarities[related_docs_indices]
# Out:
# array([1.        , 0.69430095, 0.57065178, 0.56012659, 0.55979972,
#        0.50258978, 0.49716443, 0.44439938, 0.44340904])

# %%
df.index[related_docs_indices]
# Out:
# Index(['Applied Sciences > Medicine and health',
#        'Formal Sciences > Computer Science > Computing in mathematics, natural sciences, engineering, and medicine',
#        'Applied Sciences > Medicine and health > Internal medicine',
#        'Applied Sciences > Medicine and health > Traditional medicine',
#        'Applied Sciences > Medicine and health > Alternative medicine',
#        'Applied Sciences > Medicine and health > Sports medicine',
#        'Natural Sciences > Physics > Medical physics',
#        'Social sciences > Human geography > Health geography',
#        'Social sciences > Sociology > Medical sociology'],
#       dtype='object', name='page_path_label')

# %% [markdown]
# Cool beans! There's some sense to this TF-IDF because it figues that this top ten list of interests (wikipedia articles) are related!
#
# Now very importantly, what about courses? Let's try to find matches for our test interest = **'Applied Sciences > Medicine and health'**

# %%
templist = [wiki_page_path_DF[wiki_page_path_DF.page_path_label == tempname].page_text.values[0]]
templist.extend(course_subs_DF.subtitles.astype('U').values)

# %%
#1. use vocabulary user_model_entities to get counts for all user model documents (academic interests)
vectorizer = CountVectorizer(vocabulary=list(user_model_entities), ngram_range=(1,4))
ngram_counts = vectorizer.fit_transform(templist)
#2. get TF-IDF weights
transformer = TfidfTransformer()
tfidf_matrix = transformer.fit_transform(ngram_counts)

# %%
test_index = 0
cosine_similarities = linear_kernel(tfidf_matrix[test_index:test_index+1], tfidf_matrix).flatten()
related_docs_indices = cosine_similarities.argsort()[:-5:-1];related_docs_indices
scores = cosine_similarities[related_docs_indices[1:]]
course_labels = course_subs_DF.loc[[idx-1 for idx in related_docs_indices[1:]], 'course_name']
print(list(zip(course_labels, scores)))
# Out:
# [('Intro to Health Informatics', 0.3625228519408706), ('Special Topics: Big Data for Health Informatics', 0.19956110155206086), ('Software Development Process', 0.08483674228283665)]

# %% [markdown]
# Holy crap!!!  That seems to have worked sort of well.  Let's clean this up and run it for real.
